# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv(r"E:\vinay\d.sproject\fifa\players_20.csv")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa.info
# Out:
# <bound method DataFrame.info of        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# ...

# %%
#printing all the coloumns
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
#knowing shape of fifa date
fifa.shape
# Out:
# (18278, 104)

# %%
#checking the nationality of the players
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
#top 15 country with most player
fifa['nationality'].value_counts()[0:15]
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
# Brazil                  824
# Italy                   732
# Colombia                591
# Japan                   453
# Netherlands             416
# China PR                373
# Chile                   370
# Sweden                  358
# Norway                  350
# Republic of Ireland     348
# Name: nationality, dtype: int64

# %%
#extracting the name of country without categorical value
fifa['nationality'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %%
#creating the barplot for countries from where most player come from
plt.figure(figsize=(10,10))
plt.bar(list(fifa['nationality'].value_counts()[0:10].keys()),list(fifa['nationality'].value_counts()[0:10]),color="green")
#first we have taken the country without categorical value using key() so that we can print name then we have taken the nationality with the categorical value this will give the barplot of which country have more number of player
plt.show()

# %%
#knowing the salary of player
player_salary=fifa[['short_name','wage_eur']] 
#also we have created the sub data of salary of player with there short name
print(player_salary)
# Out:
#               short_name  wage_eur
# 0               L. Messi    565000
# 1      Cristiano Ronaldo    405000
# 2              Neymar Jr    290000
# 3               J. Oblak    125000
# 4              E. Hazard    470000
# ...                  ...       ...
# 18273         Shao Shuai      2000
# 18274       Xiao Mingjie      2000
# 18275          Zhang Wei      1000
# 18276       Wang Haijian      1000
# 18277         Pan Ximing      2000
#
# [18278 rows x 2 columns]

# %%
player_salary.head(10)
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000
# 5       K. De Bruyne    370000
# 6      M. ter Stegen    250000
# 7        V. van Dijk    200000
# 8          L. Modrić    340000
# 9           M. Salah    240000

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)
print(player_salary)
# Out:
#               short_name  wage_eur
# 0               L. Messi    565000
# 4              E. Hazard    470000
# 1      Cristiano Ronaldo    405000
# 5           K. De Bruyne    370000
# 22          A. Griezmann    370000
# ...                  ...       ...
# 565         J. Serendero         0
# 1868           M. Mevlja         0
# 14723       R. Fernández         0
# 16356          H. Ivanov         0
# 3053       F. Kudryashov         0
#
# [18278 rows x 2 columns]

# %%
plt.figure(figsize=(10,10))
plt.bar(list(player_salary['short_name'].value_counts()[0:10].keys()),list(player_salary['wage_eur'].value_counts()[0:10]),color=["darkgreen","forestgreen","green","seagreen","limegreen","mediumseagreen","lime","springgreen","mediumspringgreen","mediumaquamarine"])
plt.show()
#making the barplot for player salary
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_22356\2722496337.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(list(player_salary['short_name'].value_counts()[0:10].keys()),list(player_salary['wage_eur'].value_counts()[0:10]),color=["darkgreen","forestgreen","green","seagreen","limegreen","mediumseagreen","lime","springgreen","mediumspringgreen","mediumaquamarine"])

# %% [markdown]
# # India

# %%
#searching if value is present in dataframe or not 
if 'India' in fifa.values:
    print(True)
else:
    print(False)
# Out:
# True

# %%
fifa.iloc[0]

# %%
fifa[fifa['nationality'] == 'India'].short_name
# Out:
# 12155     G. Chatterjee
# 13102          P. Bhatt
# 13103            B. Raj
# 13970    A. Chakraborty
# 13971       H. Bhandari
# 13972    A. Swaminathan
# 14625         D. Pillai
# 15204          A. Ginti
# 15205        A. Khurana
# 15321      A. Deshpande
# 15322          T. Atwal
# 15323          B. Sidhu
# 15324       R. Nadkarni
# 15809          V. Boral
# 15866       D. Sundaram
# 15867      R. Jayaraman
# 15868          D. Bajwa
# 16300          O. Patla
# 16303      P. Nagarajan
# 16352        T. Agarwal
# 16353         A. Varkay
# 16354          C. Palan
# 16714        D. Singhal
# Name: short_name, dtype: object

# %%
fifa.loc[fifa['nationality']=='India']
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 13102     251723  https://sofifa.com/player/251723/prakul-bhatt/...
# 13103     251728  https://sofifa.com/player/251728/bhadrashree-r...
# 13970     251722  https://sofifa.com/player/251722/abhimoda-chak...
# 13971     251727  https://sofifa.com/player/251727/hantidev-bhan...
# 13972     251736  https://sofifa.com/player/251736/anvit-swamina...
# 14625     251729  https://sofifa.com/player/251729/devindra-pill...
# 15204     251743  https://sofifa.com/player/251743/adit-ginti/20...
# 15205     251747  https://sofifa.com/player/251747/anuvinda-khur...
# 15321     251721  https://sofifa.com/player/251721/attana-deshpa...
# 15322     251725  https://sofifa.com/player/251725/tapish-atwal/...
# 15323     251731  https://sofifa.com/player/251731/bismeet-sidhu...
# 15324     251732  https://sofifa.com/player/251732/remil-nadkarn...
# ...

# %%
#printing the data of particualr country
print(fifa.loc[fifa['nationality']=='India'])

# %%
#checking if the nationality of player is india or not
fifa['nationality']=='India'

# %%
#extracting India values
India=fifa[fifa['nationality']=='India']
India.head(10)

# %%
#tallest player in India
India.sort_values(by=['height_cm'],ascending =False).head()

# %%
#sorting according to the weight
India.sort_values(by=['weight_kg'],ascending =False).head()

# %%
#player with most salary in India
India.sort_values(by=['weight_kg'],ascending =False).head()

# %%
#player with salary in eur
India[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending =False).head()

# %% [markdown]
# # shooting

# %%
player_shooting=fifa[['short_name','shooting']]

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()

# %% [markdown]
# # defending

# %%
player_defending=fifa[['short_name','defending','nationality','club']]

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()

# %% [markdown]
# # club

# %%
#real_madrid
real_madrid=fifa[fifa['club']=='Real Madrid']

# %%
real_madrid.sort_values(by=['wage_eur'],ascending=False).head()

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head

# %%
real_madrid['nationality'].value_counts()
